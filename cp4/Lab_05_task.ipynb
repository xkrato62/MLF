# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2)))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(X, y, epochs=2000, batch_size=1, verbose=0)

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 50.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  prediction = model.predict([data_sample])
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 [==============================] - 0s 87ms/step
# Data sample is [0, 0], prediction from model [[0.500997]], ground_truth 0
# 1/1 [==============================] - 0s 32ms/step
# Data sample is [0, 1], prediction from model [[0.5011267]], ground_truth 1
# 1/1 [==============================] - 0s 30ms/step
# Data sample is [1, 0], prediction from model [[0.49514863]], ground_truth 1
# 1/1 [==============================] - 0s 32ms/step
# Data sample is [1, 1], prediction from model [[0.49504542]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = 'drive/MyDrive/voting_complete.csv' # change the PATH
pd_dataset = pd.read_csv(path_to_dataset)

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
y_train
# Out:
# 0      republican
# 1      republican
# 2        democrat
# 3        democrat
# 4        democrat
#           ...
# 343    republican
# 344      democrat
# 345      democrat
# 346    republican
# 347    republican
# Name: Class Name, Length: 348, dtype: object

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#WRITE YOUR CODE HERE
x_train = x_test.train (('y','n','?', ),(1,-1,0))

# %%
#WRITE YOUR CODE HERE
y_train = y_train.replace (('republican','democrat'),(1,0))

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# WRITE YOU CODE HERE
model = Sequential()
model.add(Dense(8,activation='sigmoid', input_dim = 16))
model.add(Dense(8,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 8)                 72
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 217 (868.00 Byte)
# Trainable params: 217 (868.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
#cWRITE YOUR CODE HERE
history = model.fit(x_train, y_train, epochs=1000, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4771 - val_accuracy: 0.9000
# Epoch 2/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.9000
# Epoch 3/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.9000
# Epoch 4/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.9000
# Epoch 5/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.9000
# Epoch 6/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.9000
# Epoch 7/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.9000
# Epoch 8/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.9000
# Epoch 9/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.9000
# Epoch 10/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4784 - val_accuracy: 0.9000
# Epoch 11/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4785 - val_accuracy: 0.9000
# Epoch 12/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4788 - val_accuracy: 0.9000
# Epoch 13/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.9000
# Epoch 14/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4792 - val_accuracy: 0.9000
# Epoch 15/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4795 - val_accuracy: 0.9000
# Epoch 16/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4796 - val_accuracy: 0.9000
# Epoch 17/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 0.9000
# Epoch 18/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4799 - val_accuracy: 0.9000
# Epoch 19/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4802 - val_accuracy: 0.9000
# Epoch 20/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.9000
# Epoch 21/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4804 - val_accuracy: 0.9000
# Epoch 22/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.9000
# Epoch 23/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4808 - val_accuracy: 0.9000
# Epoch 24/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4809 - val_accuracy: 0.9000
# Epoch 25/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4811 - val_accuracy: 0.9000
# Epoch 26/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4813 - val_accuracy: 0.9000
# Epoch 27/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4816 - val_accuracy: 0.9000
# Epoch 28/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4818 - val_accuracy: 0.9000
# Epoch 29/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4819 - val_accuracy: 0.9000
# Epoch 30/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.9000
# Epoch 31/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4824 - val_accuracy: 0.9000
# Epoch 32/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.9000
# Epoch 33/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.9000
# Epoch 34/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4827 - val_accuracy: 0.9000
# Epoch 35/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.8857
# Epoch 36/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4829 - val_accuracy: 0.8857
# Epoch 37/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4831 - val_accuracy: 0.8857
# Epoch 38/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 0.9000
# Epoch 39/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4835 - val_accuracy: 0.8857
# Epoch 40/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.8857
# Epoch 41/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4838 - val_accuracy: 0.9000
# Epoch 42/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4839 - val_accuracy: 0.8857
# Epoch 43/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4840 - val_accuracy: 0.8857
# Epoch 44/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8857
# Epoch 45/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.8857
# Epoch 46/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.8857
# Epoch 47/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4845 - val_accuracy: 0.8857
# Epoch 48/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4847 - val_accuracy: 0.8857
# Epoch 49/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4847 - val_accuracy: 0.8857
# Epoch 50/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4849 - val_accuracy: 0.8857
# Epoch 51/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4851 - val_accuracy: 0.8857
# Epoch 52/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4852 - val_accuracy: 0.8857
# Epoch 53/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.8857
# Epoch 54/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.8857
# Epoch 55/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4856 - val_accuracy: 0.8857
# Epoch 56/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4856 - val_accuracy: 0.8857
# Epoch 57/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.8857
# Epoch 58/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.8857
# Epoch 59/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.8857
# Epoch 60/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.8857
# Epoch 61/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4863 - val_accuracy: 0.8857
# Epoch 62/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.8857
# Epoch 63/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.8857
# Epoch 64/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8857
# Epoch 65/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4868 - val_accuracy: 0.8857
# Epoch 66/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.8857
# Epoch 67/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4871 - val_accuracy: 0.8857
# Epoch 68/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 0.8857
# Epoch 69/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 0.8857
# Epoch 70/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.8857
# Epoch 71/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4876 - val_accuracy: 0.8857
# Epoch 72/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.8857
# Epoch 73/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4878 - val_accuracy: 0.8857
# Epoch 74/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.8857
# Epoch 75/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.8857
# Epoch 76/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.8857
# Epoch 77/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.8857
# Epoch 78/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4885 - val_accuracy: 0.8857
# Epoch 79/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4887 - val_accuracy: 0.8857
# Epoch 80/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.8857
# Epoch 81/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.8857
# Epoch 82/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4890 - val_accuracy: 0.8857
# Epoch 83/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.8857
# Epoch 84/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.8857
# Epoch 85/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.8857
# Epoch 86/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.8857
# Epoch 87/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4897 - val_accuracy: 0.8857
# Epoch 88/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.8857
# Epoch 89/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.8857
# Epoch 90/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.8857
# Epoch 91/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.8857
# Epoch 92/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4904 - val_accuracy: 0.8857
# Epoch 93/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4905 - val_accuracy: 0.8857
# Epoch 94/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4908 - val_accuracy: 0.8857
# Epoch 95/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.8857
# Epoch 96/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.8857
# Epoch 97/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4912 - val_accuracy: 0.8857
# Epoch 98/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8857
# Epoch 99/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.8857
# Epoch 100/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4916 - val_accuracy: 0.8857
# Epoch 101/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8857
# Epoch 102/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.8857
# Epoch 103/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.8857
# Epoch 104/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4920 - val_accuracy: 0.8857
# Epoch 105/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.8857
# Epoch 106/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4922 - val_accuracy: 0.8857
# Epoch 107/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4923 - val_accuracy: 0.8857
# Epoch 108/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.8857
# Epoch 109/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.8857
# Epoch 110/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.8857
# Epoch 111/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.8857
# Epoch 112/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4931 - val_accuracy: 0.8857
# Epoch 113/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4932 - val_accuracy: 0.8857
# Epoch 114/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4933 - val_accuracy: 0.8857
# Epoch 115/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.8857
# Epoch 116/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4936 - val_accuracy: 0.8857
# Epoch 117/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4937 - val_accuracy: 0.8857
# Epoch 118/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4938 - val_accuracy: 0.8857
# Epoch 119/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4939 - val_accuracy: 0.8857
# Epoch 120/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8857
# Epoch 121/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4941 - val_accuracy: 0.8857
# Epoch 122/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4942 - val_accuracy: 0.8857
# Epoch 123/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.8857
# Epoch 124/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.8857
# Epoch 125/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4947 - val_accuracy: 0.8857
# Epoch 126/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4948 - val_accuracy: 0.8857
# Epoch 127/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4948 - val_accuracy: 0.8857
# Epoch 128/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4949 - val_accuracy: 0.8857
# Epoch 129/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.8857
# Epoch 130/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4953 - val_accuracy: 0.8857
# Epoch 131/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4954 - val_accuracy: 0.8857
# Epoch 132/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.8857
# Epoch 133/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.8857
# Epoch 134/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4957 - val_accuracy: 0.8857
# Epoch 135/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4958 - val_accuracy: 0.8857
# Epoch 136/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.8857
# Epoch 137/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.8857
# Epoch 138/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4961 - val_accuracy: 0.8857
# Epoch 139/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4963 - val_accuracy: 0.8857
# Epoch 140/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.8857
# Epoch 141/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 0.8857
# Epoch 142/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4966 - val_accuracy: 0.8857
# Epoch 143/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4968 - val_accuracy: 0.8857
# Epoch 144/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4970 - val_accuracy: 0.8857
# Epoch 145/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4971 - val_accuracy: 0.8857
# Epoch 146/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4973 - val_accuracy: 0.8857
# Epoch 147/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4974 - val_accuracy: 0.8857
# Epoch 148/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4975 - val_accuracy: 0.8857
# Epoch 149/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.8857
# Epoch 150/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4979 - val_accuracy: 0.8857
# Epoch 151/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.8857
# Epoch 152/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.8857
# Epoch 153/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4982 - val_accuracy: 0.8857
# Epoch 154/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.8857
# Epoch 155/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4985 - val_accuracy: 0.8857
# Epoch 156/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4986 - val_accuracy: 0.8857
# Epoch 157/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.8857
# Epoch 158/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.8857
# Epoch 159/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.8857
# Epoch 160/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4990 - val_accuracy: 0.8857
# Epoch 161/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4991 - val_accuracy: 0.8857
# Epoch 162/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4992 - val_accuracy: 0.8857
# Epoch 163/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4993 - val_accuracy: 0.8857
# Epoch 164/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4995 - val_accuracy: 0.8857
# Epoch 165/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.8857
# Epoch 166/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4998 - val_accuracy: 0.8857
# Epoch 167/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.8857
# Epoch 168/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.8857
# Epoch 169/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5001 - val_accuracy: 0.8857
# Epoch 170/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.8857
# Epoch 171/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5004 - val_accuracy: 0.8857
# Epoch 172/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5005 - val_accuracy: 0.8857
# Epoch 173/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.8857
# Epoch 174/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.8857
# Epoch 175/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5010 - val_accuracy: 0.8857
# Epoch 176/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.8857
# Epoch 177/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5012 - val_accuracy: 0.8857
# Epoch 178/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.8857
# Epoch 179/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5015 - val_accuracy: 0.8857
# Epoch 180/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5017 - val_accuracy: 0.8857
# Epoch 181/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.8857
# Epoch 182/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5019 - val_accuracy: 0.8857
# Epoch 183/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5020 - val_accuracy: 0.8857
# Epoch 184/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5021 - val_accuracy: 0.8857
# Epoch 185/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.8857
# Epoch 186/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.8857
# Epoch 187/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.8857
# Epoch 188/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5027 - val_accuracy: 0.8857
# Epoch 189/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.8857
# Epoch 190/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5030 - val_accuracy: 0.8857
# Epoch 191/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.8857
# Epoch 192/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.8857
# Epoch 193/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.8857
# Epoch 194/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5036 - val_accuracy: 0.8857
# Epoch 195/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5037 - val_accuracy: 0.8857
# Epoch 196/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8857
# Epoch 197/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8857
# Epoch 198/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8857
# Epoch 199/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8857
# Epoch 200/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.8857
# Epoch 201/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8857
# Epoch 202/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5043 - val_accuracy: 0.8857
# Epoch 203/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5045 - val_accuracy: 0.8857
# Epoch 204/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5046 - val_accuracy: 0.8857
# Epoch 205/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5048 - val_accuracy: 0.8857
# Epoch 206/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.8857
# Epoch 207/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.8857
# Epoch 208/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.8857
# Epoch 209/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5053 - val_accuracy: 0.8857
# Epoch 210/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5054 - val_accuracy: 0.8857
# Epoch 211/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8857
# Epoch 212/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5057 - val_accuracy: 0.8857
# Epoch 213/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.8857
# Epoch 214/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.8857
# Epoch 215/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5060 - val_accuracy: 0.8857
# Epoch 216/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5062 - val_accuracy: 0.8857
# Epoch 217/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5063 - val_accuracy: 0.8857
# Epoch 218/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.8857
# Epoch 219/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.8857
# Epoch 220/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5066 - val_accuracy: 0.8857
# Epoch 221/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5067 - val_accuracy: 0.8857
# Epoch 222/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.8857
# Epoch 223/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5069 - val_accuracy: 0.8857
# Epoch 224/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5070 - val_accuracy: 0.8857
# Epoch 225/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5071 - val_accuracy: 0.8857
# Epoch 226/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5072 - val_accuracy: 0.8857
# Epoch 227/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5073 - val_accuracy: 0.8857
# Epoch 228/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.8857
# Epoch 229/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5075 - val_accuracy: 0.8857
# Epoch 230/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5076 - val_accuracy: 0.8857
# Epoch 231/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.8857
# Epoch 232/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5078 - val_accuracy: 0.8857
# Epoch 233/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5079 - val_accuracy: 0.8857
# Epoch 234/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5081 - val_accuracy: 0.8857
# Epoch 235/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5083 - val_accuracy: 0.8857
# Epoch 236/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5083 - val_accuracy: 0.8857
# Epoch 237/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.8857
# Epoch 238/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.8857
# Epoch 239/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.8857
# Epoch 240/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5088 - val_accuracy: 0.8857
# Epoch 241/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5088 - val_accuracy: 0.8857
# Epoch 242/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5090 - val_accuracy: 0.8857
# Epoch 243/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8857
# Epoch 244/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5092 - val_accuracy: 0.8857
# Epoch 245/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.8857
# Epoch 246/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.8857
# Epoch 247/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8857
# Epoch 248/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8857
# Epoch 249/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5097 - val_accuracy: 0.8857
# Epoch 250/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.8857
# Epoch 251/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.8857
# Epoch 252/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.8857
# Epoch 253/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5102 - val_accuracy: 0.8857
# Epoch 254/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5104 - val_accuracy: 0.8857
# Epoch 255/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5105 - val_accuracy: 0.8857
# Epoch 256/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.8857
# Epoch 257/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5107 - val_accuracy: 0.8857
# Epoch 258/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5108 - val_accuracy: 0.8857
# Epoch 259/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.8857
# Epoch 260/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5112 - val_accuracy: 0.8857
# Epoch 261/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.8857
# Epoch 262/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.8857
# Epoch 263/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.8857
# Epoch 264/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.8857
# Epoch 265/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.8857
# Epoch 266/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5118 - val_accuracy: 0.8857
# Epoch 267/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5119 - val_accuracy: 0.8857
# Epoch 268/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5120 - val_accuracy: 0.8857
# Epoch 269/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8857
# Epoch 270/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8857
# Epoch 271/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5122 - val_accuracy: 0.8857
# Epoch 272/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5123 - val_accuracy: 0.8857
# Epoch 273/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5124 - val_accuracy: 0.8857
# Epoch 274/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.8857
# Epoch 275/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.8857
# Epoch 276/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5126 - val_accuracy: 0.8857
# Epoch 277/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.8857
# Epoch 278/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.8857
# Epoch 279/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.8857
# Epoch 280/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5132 - val_accuracy: 0.8857
# Epoch 281/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5133 - val_accuracy: 0.8857
# Epoch 282/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.8857
# Epoch 283/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.8857
# Epoch 284/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5137 - val_accuracy: 0.8857
# Epoch 285/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.8857
# Epoch 286/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5140 - val_accuracy: 0.8857
# Epoch 287/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5141 - val_accuracy: 0.8857
# Epoch 288/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.8857
# Epoch 289/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.8857
# Epoch 290/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5143 - val_accuracy: 0.8857
# Epoch 291/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5145 - val_accuracy: 0.8857
# Epoch 292/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5145 - val_accuracy: 0.8857
# Epoch 293/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.8857
# Epoch 294/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8857
# Epoch 295/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8857
# Epoch 296/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8857
# Epoch 297/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8857
# Epoch 298/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.8857
# Epoch 299/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8857
# Epoch 300/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.8857
# Epoch 301/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5155 - val_accuracy: 0.8857
# Epoch 302/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.8857
# Epoch 303/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.8857
# Epoch 304/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.8857
# Epoch 305/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8857
# Epoch 306/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5160 - val_accuracy: 0.8857
# Epoch 307/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8857
# Epoch 308/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8857
# Epoch 309/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.8857
# Epoch 310/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8857
# Epoch 311/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.8857
# Epoch 312/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.8857
# Epoch 313/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.8857
# Epoch 314/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.8857
# Epoch 315/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.8857
# Epoch 316/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.8857
# Epoch 317/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8857
# Epoch 318/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8857
# Epoch 319/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5174 - val_accuracy: 0.8857
# Epoch 320/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 0.8857
# Epoch 321/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.8857
# Epoch 322/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.8857
# Epoch 323/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5178 - val_accuracy: 0.8857
# Epoch 324/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5179 - val_accuracy: 0.8857
# Epoch 325/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8857
# Epoch 326/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.8857
# Epoch 327/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.8857
# Epoch 328/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.8857
# Epoch 329/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5185 - val_accuracy: 0.8857
# Epoch 330/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.8857
# Epoch 331/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5187 - val_accuracy: 0.8857
# Epoch 332/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5188 - val_accuracy: 0.8857
# Epoch 333/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.8857
# Epoch 334/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.8857
# Epoch 335/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.8857
# Epoch 336/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5192 - val_accuracy: 0.8857
# Epoch 337/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.8857
# Epoch 338/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.8857
# Epoch 339/1000
# ...
# Epoch 889/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5649 - val_accuracy: 0.9000
# Epoch 890/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5650 - val_accuracy: 0.9000
# Epoch 891/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5650 - val_accuracy: 0.9000
# Epoch 892/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5651 - val_accuracy: 0.9000
# Epoch 893/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5652 - val_accuracy: 0.9000
# Epoch 894/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5653 - val_accuracy: 0.9000
# Epoch 895/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5654 - val_accuracy: 0.9000
# Epoch 896/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5654 - val_accuracy: 0.9000
# Epoch 897/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5655 - val_accuracy: 0.9000
# Epoch 898/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5655 - val_accuracy: 0.9000
# Epoch 899/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5656 - val_accuracy: 0.9000
# Epoch 900/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5657 - val_accuracy: 0.9000
# Epoch 901/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5657 - val_accuracy: 0.9000
# Epoch 902/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5658 - val_accuracy: 0.9000
# Epoch 903/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5658 - val_accuracy: 0.9000
# Epoch 904/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.9000
# Epoch 905/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5660 - val_accuracy: 0.9000
# Epoch 906/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5661 - val_accuracy: 0.9000
# Epoch 907/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5662 - val_accuracy: 0.9000
# Epoch 908/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5663 - val_accuracy: 0.9000
# Epoch 909/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5664 - val_accuracy: 0.9000
# Epoch 910/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5665 - val_accuracy: 0.9000
# Epoch 911/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5665 - val_accuracy: 0.9000
# Epoch 912/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5666 - val_accuracy: 0.9000
# Epoch 913/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5666 - val_accuracy: 0.9000
# Epoch 914/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5668 - val_accuracy: 0.9000
# Epoch 915/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5668 - val_accuracy: 0.9000
# Epoch 916/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5669 - val_accuracy: 0.9000
# Epoch 917/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5669 - val_accuracy: 0.9000
# Epoch 918/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5669 - val_accuracy: 0.9000
# Epoch 919/1000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5671 - val_accuracy: 0.9000
# Epoch 920/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5671 - val_accuracy: 0.9000
# Epoch 921/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5672 - val_accuracy: 0.9000
# Epoch 922/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5673 - val_accuracy: 0.9000
# Epoch 923/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5673 - val_accuracy: 0.9000
# Epoch 924/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5674 - val_accuracy: 0.9000
# Epoch 925/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5675 - val_accuracy: 0.9000
# Epoch 926/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5676 - val_accuracy: 0.9000
# Epoch 927/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5676 - val_accuracy: 0.9000
# Epoch 928/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5677 - val_accuracy: 0.9000
# Epoch 929/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5677 - val_accuracy: 0.9000
# Epoch 930/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5678 - val_accuracy: 0.9000
# Epoch 931/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5679 - val_accuracy: 0.9000
# Epoch 932/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 0.9000
# Epoch 933/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 0.9000
# Epoch 934/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5681 - val_accuracy: 0.9000
# Epoch 935/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5681 - val_accuracy: 0.9000
# Epoch 936/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 0.9000
# Epoch 937/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 0.9000
# Epoch 938/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5683 - val_accuracy: 0.9000
# Epoch 939/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5684 - val_accuracy: 0.9000
# Epoch 940/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5684 - val_accuracy: 0.9000
# Epoch 941/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5685 - val_accuracy: 0.9000
# Epoch 942/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5685 - val_accuracy: 0.9000
# Epoch 943/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5686 - val_accuracy: 0.9000
# Epoch 944/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5686 - val_accuracy: 0.9000
# Epoch 945/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5686 - val_accuracy: 0.9000
# Epoch 946/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5687 - val_accuracy: 0.9000
# Epoch 947/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 0.9000
# Epoch 948/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 0.9000
# Epoch 949/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5689 - val_accuracy: 0.9000
# Epoch 950/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5689 - val_accuracy: 0.9000
# Epoch 951/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 0.9000
# Epoch 952/1000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.9000
# Epoch 953/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5692 - val_accuracy: 0.9000
# Epoch 954/1000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5693 - val_accuracy: 0.9000
# Epoch 955/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5693 - val_accuracy: 0.9000
# Epoch 956/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 0.9000
# Epoch 957/1000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 0.9000
# Epoch 958/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.9000
# Epoch 959/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5696 - val_accuracy: 0.9000
# Epoch 960/1000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5696 - val_accuracy: 0.9000
# Epoch 961/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.9000
# Epoch 962/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5698 - val_accuracy: 0.9000
# Epoch 963/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.9000
# Epoch 964/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.9000
# Epoch 965/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 0.9000
# Epoch 966/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 0.9000
# Epoch 967/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 0.9000
# Epoch 968/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5702 - val_accuracy: 0.9000
# Epoch 969/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5702 - val_accuracy: 0.9000
# Epoch 970/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5703 - val_accuracy: 0.9000
# Epoch 971/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 0.9000
# Epoch 972/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 0.9000
# Epoch 973/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5705 - val_accuracy: 0.9000
# Epoch 974/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5705 - val_accuracy: 0.9000
# Epoch 975/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5706 - val_accuracy: 0.9000
# Epoch 976/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 0.9000
# Epoch 977/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 0.9000
# Epoch 978/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.9000
# Epoch 979/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.9000
# Epoch 980/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.9000
# Epoch 981/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.9000
# Epoch 982/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 0.9000
# Epoch 983/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 0.9000
# Epoch 984/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 0.9000
# Epoch 985/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 0.9000
# Epoch 986/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5713 - val_accuracy: 0.9000
# Epoch 987/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5713 - val_accuracy: 0.9000
# Epoch 988/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5714 - val_accuracy: 0.9000
# Epoch 989/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5714 - val_accuracy: 0.9000
# Epoch 990/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5715 - val_accuracy: 0.9000
# Epoch 991/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.9000
# Epoch 992/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.9000
# Epoch 993/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.9000
# Epoch 994/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5717 - val_accuracy: 0.9000
# Epoch 995/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5717 - val_accuracy: 0.9000
# Epoch 996/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5718 - val_accuracy: 0.9000
# Epoch 997/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.9000
# Epoch 998/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.9000
# Epoch 999/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.9000
# Epoch 1000/1000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5720 - val_accuracy: 0.9000

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE
x_test = x_test.replace (('y','n','?', ),(1,-1,0))
y_test = y_test.replace (('republican','democrat'),(1,0))

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 93.10

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')
